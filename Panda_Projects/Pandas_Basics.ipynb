# %% [markdown]
# # 🐼 Python Pandas Cheat Sheet

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"],index=["x","y","z"])

# %%
df.head() #we can look at the specific rows by using df.head(row number)
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(1)      #tail to look at the end of data
# Out:
#    A  B  C
# 2  7  8  9

# %%
df.columns     #to look at the headders of the dataset
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index     #to view index of the list
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.index.tolist()     #to view the indexes in a list
# Out:
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()     #to find math values of the data like mean median mode etc...
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()     #to find no of unq values in each column
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %% [markdown]
# ## Practicing on Small Dataset
#  coffee shop data from coffee.csv in datasets

# %%
coffee= pd.read_csv('coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_csv('results.csv')
bios = pd.read_csv('bios.csv')
olympics_data = pd.read_excel('olympics-data.xlsx', sheet_name="results")

# %% [markdown]
#  ## Accessing Data with Pandas

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(10     #gives random 10 values
# Out:
#           Day Coffee Type  Units Sold
# 9      Friday       Latte          35
# 1      Monday       Latte          15
# 10   Saturday    Espresso          45
# 5   Wednesday       Latte          25
# 11   Saturday       Latte          35
# 3     Tuesday       Latte          20
# 6    Thursday    Espresso          40
# 0      Monday    Espresso          25
# 12     Sunday    Espresso          45
# 7    Thursday       Latte          30

# %%
coffee.head(10)     #acess top 10 elements
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail()     #accesing only last 5 values by default
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.tail(10)     #accesing last 10 rows of the data
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ### loc and iloc

# %%
coffee.loc[0]     #coffee.loc[row,column]to view specific columns and rows of data we use loc or iloc
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,4,5]]     #specific rows
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
coffee.loc[0:8]     #slicing is possible in loc accesing
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45

# %%
coffee.loc[0:8,["Day","Units Sold"]]     # you can use combination of rows and columns acccesing
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
coffee.iloc[:,[0,2]]      
#iloc is similar to loc but insted of using labels like day and units sold we use indexing in iloc
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %% [markdown]
# ## Assigining Values

# %%
coffee.loc[1,'Units Sold']=10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ### Using at and iat

# %%
coffee.at[0,"Units Sold"]      #at and iat can be used to access only that one single value
# Out:
# np.int64(25)

# %% [markdown]
# ### Getting Columns

# %%
coffee.Day         #works with non spaced column names
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.Units Sold      #doesnt work with column nams with space
# Out:
#   Cell In[102], line 1
#     coffee.Units Sold      #doesnt work with column nams with space
#                  ^
# SyntaxError: invalid syntax

# %%
coffee["Units Sold"]      #this is how you work with column names wih spaces
# Out:
# 0     25
# 1     10
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %% [markdown]
# ### Sort Values

# %%
coffee.sort_values(["Units Sold"],ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %%
coffee.sort_values(["Units Sold","Coffee Type"], ascending=False)      
#first it will sort by units sold and next it will again sort by lexographical/alphabeticall values look at the diff between previous and now sorting prev:10 8 12 6 4   but now the order is 8 10 12 6 9
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %% [markdown]
# ### Iterate over dataframe with for loop

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print("Coffee Type of Row:", row["Coffee Type"])
    # not recommended to iterate in datasets it might loose performance
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# Coffee Type of Row: Espresso
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
# Coffee Type of Row: Latte
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
# Coffee Type of Row: Espresso
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
# Coffee Type of Row: Latte
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# Coffee Type of Row: Espresso
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# Coffee Type of Row: Latte
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# Coffee Type of Row: Espresso
# 7
# Day            Thursday
# ...

# %% [markdown]
# ## Adding and Removing Columns

# %%
 coffee["Price"]=4.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
coffee['new_price']=np.where(coffee['Coffee Type']=='Espresso',3.99,5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee.drop(columns=["Price"])
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          15   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(columns=["Price"],inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee_new=coffee       
#here you are not creating a new dataset just that coffee_new is pointing towards coffee 
#so any change in coffee_new is also reflected in coffee 
#to fix that to create a new dataset to actually copy a dataset to a new variable u use .copy()

# %%
coffee_new["price"]=6.99

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  new_price  price
# 0      Monday    Espresso          25       3.99   6.99
# 1      Monday       Latte          15       5.99   6.99
# 2     Tuesday    Espresso          30       3.99   6.99
# 3     Tuesday       Latte          20       5.99   6.99
# 4   Wednesday    Espresso          35       3.99   6.99
# 5   Wednesday       Latte          25       5.99   6.99
# 6    Thursday    Espresso          40       3.99   6.99
# 7    Thursday       Latte          30       5.99   6.99
# 8      Friday    Espresso          45       3.99   6.99
# 9      Friday       Latte          35       5.99   6.99
# 10   Saturday    Espresso          45       3.99   6.99
# 11   Saturday       Latte          35       5.99   6.99
# 12     Sunday    Espresso          45       3.99   6.99
# 13     Sunday       Latte          35       5.99   6.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  price
# 0      Monday    Espresso          25       3.99   6.99
# 1      Monday       Latte          15       5.99   6.99
# 2     Tuesday    Espresso          30       3.99   6.99
# 3     Tuesday       Latte          20       5.99   6.99
# 4   Wednesday    Espresso          35       3.99   6.99
# 5   Wednesday       Latte          25       5.99   6.99
# 6    Thursday    Espresso          40       3.99   6.99
# 7    Thursday       Latte          30       5.99   6.99
# 8      Friday    Espresso          45       3.99   6.99
# 9      Friday       Latte          35       5.99   6.99
# 10   Saturday    Espresso          45       3.99   6.99
# 11   Saturday       Latte          35       5.99   6.99
# 12     Sunday    Espresso          45       3.99   6.99
# 13     Sunday       Latte          35       5.99   6.99

# %%
coffee_new.drop(columns="price",inplace=True)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee_dup=coffee.copy()

# %%
coffee_dup["Price"]=7.99

# %%
coffee_dup
# Out:
#           Day Coffee Type  Units Sold  new_price  Price
# 0      Monday    Espresso          25       3.99   7.99
# 1      Monday       Latte          15       5.99   7.99
# 2     Tuesday    Espresso          30       3.99   7.99
# 3     Tuesday       Latte          20       5.99   7.99
# 4   Wednesday    Espresso          35       3.99   7.99
# 5   Wednesday       Latte          25       5.99   7.99
# 6    Thursday    Espresso          40       3.99   7.99
# 7    Thursday       Latte          30       5.99   7.99
# 8      Friday    Espresso          45       3.99   7.99
# 9      Friday       Latte          35       5.99   7.99
# 10   Saturday    Espresso          45       3.99   7.99
# 11   Saturday       Latte          35       5.99   7.99
# 12     Sunday    Espresso          45       3.99   7.99
# 13     Sunday       Latte          35       5.99   7.99

# %%
coffee
#no effect on coffee dataset bcoz of coffee_dup
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee["Revenue"]=coffee["Units Sold"]*coffee["new_price"]

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={"new_price":"Price"})
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
coffee
#no Price in place of new_price because we need to do inplace=True for it
#or else make it- coffee=coffee.rename(columns={"new_price":"Price"})
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={"new_price":"Price"},inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## Handling Null Values

# %%
coffee.loc[[0,1],"Units Sold"]=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso         NaN
# 1      Monday       Latte         NaN
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   12 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 468.0+ bytes

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# dtype: int64

# %%
coffee.fillna(1000000)
#directly replace it with a value
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   1000000.0
# 1      Monday       Latte   1000000.0
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.loc[[0,1],"Units Sold"]=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso         NaN
# 1      Monday       Latte         NaN
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee=coffee.fillna(coffee["Units Sold"].mean())
#fill it with mean of the column

# %%
coffee.loc[[2,3],"Units Sold"]=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        37.0
# 1      Monday       Latte        37.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee["Units Sold"]=coffee["Units Sold"].interpolate()
#interpolate relates it with neighbouring patterns

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   37.000000
# 1      Monday       Latte   37.000000
# 2     Tuesday    Espresso   36.333333
# 3     Tuesday       Latte   35.666667
# 4   Wednesday    Espresso   35.000000
# 5   Wednesday       Latte   25.000000
# 6    Thursday    Espresso   40.000000
# 7    Thursday       Latte   30.000000
# 8      Friday    Espresso   45.000000
# 9      Friday       Latte   35.000000
# 10   Saturday    Espresso   45.000000
# 11   Saturday       Latte   35.000000
# 12     Sunday    Espresso   45.000000
# 13     Sunday       Latte   35.000000

# %%
coffee.loc[[2,3],"Units Sold"]=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        37.0
# 1      Monday       Latte        37.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.dropna()
#drop data with null values
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        37.0
# 1      Monday       Latte        37.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.loc[[2,3],"Units Sold"]=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        37.0
# 1      Monday       Latte        37.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee[coffee["Units Sold"].isna()]
# Out:
#        Day Coffee Type  Units Sold
# 2  Tuesday    Espresso         NaN
# 3  Tuesday       Latte         NaN

# %%
coffee[coffee["Units Sold"].notna()]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## Aggregating Data

# %%
coffee.groupby(['Coffee Type'])["Units Sold"].sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       195
# Name: Units Sold, dtype: int64

# %%
coffee.groupby(['Coffee Type'])["Units Sold"].mean()
# Out:
# Coffee Type
# Espresso    37.857143
# Latte       27.857143
# Name: Units Sold, dtype: float64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
pivot=coffee.pivot(columns="Coffee Type",index="Day",values="Units Sold")

# %%
pivot
# Out:
# Coffee Type  Espresso  Latte
# Day
# Friday             45     35
# Monday             25     15
# Saturday           45     35
# Sunday             45     35
# Thursday           40     30
# Tuesday            30     20
# Wednesday          35     25

# %% [markdown]
# ## Advanced Functionality

# %%
# .shift()  .rank()  .rolling()  .cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee["yesterday_revenue"]=coffee["Revenue"].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue  yesterday_revenue
# 0      Monday    Espresso          25       3.99    99.75                NaN
# 1      Monday       Latte          15       5.99    89.85                NaN
# 2     Tuesday    Espresso          30       3.99   119.70              99.75
# 3     Tuesday       Latte          20       5.99   119.80              89.85
# 4   Wednesday    Espresso          35       3.99   139.65             119.70
# 5   Wednesday       Latte          25       5.99   149.75             119.80
# 6    Thursday    Espresso          40       3.99   159.60             139.65
# 7    Thursday       Latte          30       5.99   179.70             149.75
# 8      Friday    Espresso          45       3.99   179.55             159.60
# 9      Friday       Latte          35       5.99   209.65             179.70
# 10   Saturday    Espresso          45       3.99   179.55             179.55
# ...

# %%
coffee["pct_change"]=coffee['Revenue']/coffee["yesterday_revenue"]*100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue  yesterday_revenue  \
# 0      Monday    Espresso          25       3.99    99.75                NaN
# 1      Monday       Latte          15       5.99    89.85                NaN
# 2     Tuesday    Espresso          30       3.99   119.70              99.75
# 3     Tuesday       Latte          20       5.99   119.80              89.85
# 4   Wednesday    Espresso          35       3.99   139.65             119.70
# 5   Wednesday       Latte          25       5.99   149.75             119.80
# 6    Thursday    Espresso          40       3.99   159.60             139.65
# 7    Thursday       Latte          30       5.99   179.70             149.75
# 8      Friday    Espresso          45       3.99   179.55             159.60
# 9      Friday       Latte          35       5.99   209.65             179.70
# 10   Saturday    Espresso          45       3.99   179.55             179.55
# ...

# %%
coffee["cumulative_revenue"]=coffee['Revenue'].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue  yesterday_revenue  \
# 0      Monday    Espresso          25       3.99    99.75                NaN
# 1      Monday       Latte          15       5.99    89.85                NaN
# 2     Tuesday    Espresso          30       3.99   119.70              99.75
# 3     Tuesday       Latte          20       5.99   119.80              89.85
# 4   Wednesday    Espresso          35       3.99   139.65             119.70
# 5   Wednesday       Latte          25       5.99   149.75             119.80
# 6    Thursday    Espresso          40       3.99   159.60             139.65
# 7    Thursday       Latte          30       5.99   179.70             149.75
# 8      Friday    Espresso          45       3.99   179.55             159.60
# 9      Friday       Latte          35       5.99   209.65             179.70
# 10   Saturday    Espresso          45       3.99   179.55             179.55
# ...

# %%
latte=coffee[coffee['Coffee Type']=='Latte'].copy()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue  yesterday_revenue  \
# 1      Monday       Latte          15       5.99    89.85                NaN
# 3     Tuesday       Latte          20       5.99   119.80              89.85
# 5   Wednesday       Latte          25       5.99   149.75             119.80
# 7    Thursday       Latte          30       5.99   179.70             149.75
# 9      Friday       Latte          35       5.99   209.65             179.70
# 11   Saturday       Latte          35       5.99   209.65             209.65
# 13     Sunday       Latte          35       5.99   209.65             209.65
#
#     pct_change  cumulative_revenue
# 1          NaN               189.6
# 3   133.333333               429.1
# 5   125.000000               718.5
# 7   120.000000              1057.8
# 9   116.666667              1447.0
# 11  100.000000              1836.2
# 13  100.000000              2225.4

# %%
latte['3day']=latte['Units Sold'].rolling(3).sum()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue  yesterday_revenue  \
# 1      Monday       Latte          15       5.99    89.85                NaN
# 3     Tuesday       Latte          20       5.99   119.80              89.85
# 5   Wednesday       Latte          25       5.99   149.75             119.80
# 7    Thursday       Latte          30       5.99   179.70             149.75
# 9      Friday       Latte          35       5.99   209.65             179.70
# 11   Saturday       Latte          35       5.99   209.65             209.65
# 13     Sunday       Latte          35       5.99   209.65             209.65
#
#     pct_change  cumulative_revenue   3day
# 1          NaN               189.6    NaN
# 3   133.333333               429.1    NaN
# 5   125.000000               718.5   60.0
# 7   120.000000              1057.8   75.0
# 9   116.666667              1447.0   90.0
# 11  100.000000              1836.2  100.0
# 13  100.000000              2225.4  105.0
